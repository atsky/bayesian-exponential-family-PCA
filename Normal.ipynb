# %%
import pymc3 as pm
import numpy as np
from numpy import random
import pylab as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
x = random.normal(loc=1.0, scale=2.0, size=200)

# %%
with pm.Model() as model:
    # TODO
    m = pm.Normal('m',0, 1)
    sd = pm.Gamma('sd', 1, 1)
    
    x= pm.Normal('x', m, sd)
    
    start = pm.find_MAP()
    step = pm.NUTS()
    trace = pm.sample(1000, start=start, step=step)
# Out:
# Optimization terminated successfully.
#          Current function value: 1.837883
#          Iterations: 17
#          Function evaluations: 18
#          Gradient evaluations: 18
# 100%|██████████| 1000/1000 [08:24<00:00,  1.98it/s]

# %%
pm.traceplot(trace)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6936dc4668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f692cac5b00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f692ca89748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f692ca68f28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f692c9cc048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f692c939198>]], dtype=object)
